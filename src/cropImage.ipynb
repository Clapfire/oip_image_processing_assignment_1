# %% [markdown]
# # Load Image (Start your project)
# Get Off to a Running Start with the Necessary Imports Below

# %%
#un comment the following lines to use sci-kit tips on the exercise (ie, shortcuts need to be taken):
#https://scikit-image.org/docs/stable/auto_examples/segmentation/plot_label.html#sphx-glr-auto-examples-segmentation-plot-label-py

#from skimage import data
#from skimage.filters import threshold_otsu
#from skimage.segmentation import clear_border
#from skimage.measure import label, regionprops
#from skimage.morphology import closing, square
#from skimage.color import label2rgb
#import matplotlib.patches as mpatches

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np 
import modules.oiplib as ip
import math

# %matplotlib inline

#This line is specific for mac users with retina display
# %config InlineBackend.figure_format = 'retina'

#from ipywidgets import interact, interactive, fixed, interact_manual
#from ipywidgets import widgets

# %%
imgurl = '../images/heptamers.tiff'
img = ip.loadImage(imgurl)
fig,ax = ip.showImage(img, figsize=10)

# %%
#to find point to crop:

threshimg = ip.threshold_binary2(img,50)
condt = np.ones(threshimg.shape[1],dtype=np.uint8)

b = []
for i in range(threshimg.shape[0]):
    b.append(np.array_equal(threshimg[i], condt))
b.index(True)
# Out:
# 884

# %%
crop = img[:884,:]
fig,ax = ip.showImage(crop,figsize=10)
# Out:
# (<Figure size 720x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12147b290>)

# %%
#function for use in the library

def remove_legend(img):
    """input parameter needs to be np array """
    return img[:884,:]
