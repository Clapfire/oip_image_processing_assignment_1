# %% [markdown]
# # Example
#
# A simple example how to use the `oiplib5`.

# %%
# Import the image processing library.
import modules.oiplib5 as oiplib5

# %%
# Load and show image.
uint8Img = oiplib5.loadImage('../images/heptamers.tiff');
oiplib5.showImage(uint8Img, figsize=10);
